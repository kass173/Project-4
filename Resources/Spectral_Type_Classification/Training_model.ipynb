# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
stardf = pd.read_csv("TG_stars.csv")
stardf.head (7)
# Out:
#     Vmag    Plx  e_Plx    B-V       Amag  TargetClass
# 0   9.10   3.54   1.39  0.482  16.845016            3
# 1   9.27  21.90   3.10  0.999  20.972221            5
# 2   6.61   2.81   0.63 -0.019  13.853532            1
# 3   8.06   7.75   0.97  0.370  17.506509            3
# 4   8.55   2.87   1.11  0.902  15.839409            4
# 5  12.31  18.80   4.99  1.336  23.680789            6
# 6   9.64  17.74   1.30  0.740  20.884768            4

# %%
stardf.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9677 entries, 0 to 9676
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Vmag         9677 non-null   float64
#  1   Plx          9677 non-null   float64
#  2   e_Plx        9677 non-null   float64
#  3   B-V          9677 non-null   float64
#  4   Amag         9677 non-null   float64
#  5   TargetClass  9677 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 453.7 KB

# %%
stardf.describe ()
# Out:
#               Vmag          Plx        e_Plx          B-V         Amag  \
# count  9677.000000  9677.000000  9677.000000  9677.000000  9677.000000
# mean      8.407528     7.545683     1.296913     0.742986    16.730993
# std       1.253150    11.040561     1.187446     0.454976     2.460227
# min       0.450000   -18.170000     0.470000    -0.359000     2.820000
# 25%       7.710000     2.730000     0.910000     0.419000    15.389369
# 50%       8.520000     4.920000     1.110000     0.644000    16.698435
# 75%       9.170000     8.760000     1.360000     1.083000    18.220190
# max      12.810000   280.270000    33.050000     2.835000    29.249165
#
#        TargetClass
# count  9677.000000
# mean      3.681823
# std       1.304717
# min       0.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       7.000000

# %% [markdown]
# # Visualising the Dataset

# %%
zero = 0
one = 1
two=2
three=3
four=4
five=5
six=6
seven=7

# %%
groupzero = stardf.query('TargetClass ==  @zero')[['Vmag','Plx','e_Plx','B-V', 'Amag']] 
groupone = stardf.query('TargetClass ==  @one')[['Vmag','Plx','e_Plx','B-V', 'Amag']]
grouptwo = stardf.query('TargetClass ==  @two')[['Vmag','Plx','e_Plx','B-V', 'Amag']]
groupthree = stardf.query('TargetClass ==  @three')[['Vmag','Plx','e_Plx','B-V', 'Amag']]
groupfour = stardf.query('TargetClass ==  @four')[['Vmag','Plx','e_Plx','B-V', 'Amag']]
groupfive = stardf.query('TargetClass ==  @five')[['Vmag','Plx','e_Plx','B-V', 'Amag']]
groupsix = stardf.query('TargetClass ==  @six')[['Vmag','Plx','e_Plx','B-V', 'Amag']]
groupseven = stardf.query('TargetClass ==  @seven')[['Vmag','Plx','e_Plx','B-V', 'Amag']]

# %% [markdown]
# ## Vmag Vs B-V

# %%
sc, ax1 = plt.subplots(figsize=(12, 9))


ax1.scatter(groupzero['Vmag'], groupzero['B-V'], s=10, c='#0e64ed', marker="o", label='zero')
ax1.scatter(groupone['Vmag'], groupone['B-V'], s=10, c='#4196c4', marker="o", label='one')
ax1.scatter(grouptwo['Vmag'], grouptwo['B-V'], s=10, c='#41c0c4', marker="o", label='two')
ax1.scatter(groupthree['Vmag'], groupthree['B-V'], s=10, c='#5f9396', marker="o", label='three')
ax1.scatter(groupfour['Vmag'], groupfour['B-V'], s=10, c='#f5ec4e', marker="o", label='four')
ax1.scatter(groupfive['Vmag'], groupfive['B-V'], s=10, c='#f08513', marker="o", label='five')
ax1.scatter(groupsix['Vmag'], groupsix['B-V'], s=10, c='#bf1515', marker="o", label='six')
ax1.scatter(groupseven['Vmag'], groupseven['B-V'], s=10, c='black', marker="o", label='seven')

plt.xlabel('Apparent Magnitude',fontsize =14)
plt.ylabel('B-V',fontsize=14)


plt.legend ()
plt.show ()

# %% [markdown]
# ## AMag Vs B-V

# %%
sc, ax1 = plt.subplots(figsize=(12, 9))

ax1.scatter(groupzero['Amag'], groupzero['B-V'], s=10, c='#0e64ed', marker="o", label='zero')
ax1.scatter(groupone['Amag'], groupone['B-V'], s=10, c='#4196c4', marker="o", label='one')
ax1.scatter(grouptwo['Amag'], grouptwo['B-V'], s=10, c='#41c0c4', marker="o", label='two')
ax1.scatter(groupthree['Amag'], groupthree['B-V'], s=10, c='#5f9396', marker="o", label='three')
ax1.scatter(groupfour['Amag'], groupfour['B-V'], s=10, c='#f5ec4e', marker="o", label='four')
ax1.scatter(groupfive['Amag'], groupfive['B-V'], s=10, c='#f08513', marker="o", label='five')
ax1.scatter(groupsix['Amag'], groupsix['B-V'], s=10, c='#bf1515', marker="o", label='six')
ax1.scatter(groupseven['Amag'], groupseven['B-V'], s=10, c='black', marker="o", label='seven')

plt.xlabel('Absolute Magnitude',fontsize =14)
plt.ylabel('B-V',fontsize=14)


plt.legend ()
plt.show ()

# %% [markdown]
# ## Vmag Vs Plx

# %%
sc, ax1 = plt.subplots(figsize=(12, 9))

ax1.scatter(groupzero['Vmag'], groupzero['Plx'], s=10, c='#0e64ed', marker="o", label='zero')
ax1.scatter(groupone['Vmag'], groupone['Plx'], s=10, c='#4196c4', marker="o", label='one')
ax1.scatter(grouptwo['Vmag'], grouptwo['Plx'], s=10, c='#41c0c4', marker="o", label='two')
ax1.scatter(groupthree['Vmag'], groupthree['Plx'], s=10, c='#5f9396', marker="o", label='three')
ax1.scatter(groupfour['Vmag'], groupfour['Plx'], s=10, c='#f5ec4e', marker="o", label='four')
ax1.scatter(groupfive['Vmag'], groupfive['Plx'], s=10, c='#f08513', marker="o", label='five')
ax1.scatter(groupsix['Vmag'], groupsix['Plx'], s=10, c='#bf1515', marker="o", label='six')
ax1.scatter(groupseven['Vmag'], groupseven['Plx'], s=10, c='black', marker="o", label='seven')

plt.xlabel('Apparent Magnitude',fontsize =14)
plt.ylabel('Plx',fontsize=14)

plt.legend ()
plt.show ()

# %% [markdown]
# ## Amag Vs Plx

# %%
sc, ax1 = plt.subplots(figsize=(12, 9))

ax1.scatter(groupzero['Amag'], groupzero['Plx'], s=10, c='#0e64ed', marker="o", label='zero')
ax1.scatter(groupone['Amag'], groupone['Plx'], s=10, c='#4196c4', marker="o", label='one')
ax1.scatter(grouptwo['Amag'], grouptwo['Plx'], s=10, c='#41c0c4', marker="o", label='two')
ax1.scatter(groupthree['Amag'], groupthree['Plx'], s=10, c='#5f9396', marker="o", label='three')
ax1.scatter(groupfour['Amag'], groupfour['Plx'], s=10, c='#f5ec4e', marker="o", label='four')
ax1.scatter(groupfive['Amag'], groupfive['Plx'], s=10, c='#f08513', marker="o", label='five')
ax1.scatter(groupsix['Amag'], groupsix['Plx'], s=10, c='#bf1515', marker="o", label='six')
ax1.scatter(groupseven['Amag'], groupseven['Plx'], s=10, c='black', marker="o", label='seven')

plt.xlabel('Absolute Magnitude',fontsize =14)
plt.ylabel('Plx',fontsize=14)

plt.grid ()
plt.legend ()
plt.show ()
#plt.subplot to plt.figure()

# %%
fig, axes = plt.subplots(1,2, figsize=(20,10))

sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==0], color= '#0e64ed', shade=True, ax = axes[0],label='zero')
sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==1], color= '#4196c4', shade=True, ax = axes[0],label='one')
sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==2], color= '#41c0c4', shade=True, ax = axes[0],label='two')
sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==3], color= '#5f9396', shade=True, ax = axes[0],label='three')
sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==4], color= '#f5ec4e', shade=True, ax = axes[0],label='four')
sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==5], color= '#f08513', shade=True, ax = axes[0],label='five')
sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==6], color= '#bf1515', shade=True, ax = axes[0],label='six')
sns.kdeplot(data = stardf['Amag'].loc[stardf['TargetClass']==7], color= 'black', shade=True, ax = axes[0],label='seven')
axes[0].legend()

axes[0].set_xlabel('Absolute Magnitude', size=14)

sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==0], color= '#0e64ed', shade=True, ax = axes[1],label='zero')
sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==1], color= '#4196c4', shade=True, ax = axes[1],label='one')
sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==2], color= '#41c0c4', shade=True, ax = axes[1],label='two')
sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==3], color= '#5f9396', shade=True, ax = axes[1],label='three')
sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==4], color= '#f5ec4e', shade=True, ax = axes[1],label='four')
sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==5], color= '#f08513', shade=True, ax = axes[1],label='five')
sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==6], color= '#bf1515', shade=True, ax = axes[1],label='six')
sns.kdeplot(data = stardf['Vmag'].loc[stardf['TargetClass']==7], color= 'black', shade=True, ax = axes[1],label='seven')
axes[1].legend()

axes[1].set_xlabel('Apparent Magnitude', size=14)
# Out:
# Text(0.5, 0, 'Apparent Magnitude')

# %% [markdown]
# #### It's pretty clear from the data that everything is too clustered.

# %% [markdown]
# ## Feature Engineering

# %%
stars_df_features = stardf.copy()

stars_df_features['Amag_SQ'] = stars_df_features['Amag']**2
stars_df_features['Vmag_SQ'] = stars_df_features['Vmag']**2
stars_df_features['B-V_SQ'] = stars_df_features['B-V']**2
stars_df_features['Sum_AV'] = stars_df_features['Amag'] + stars_df_features['Vmag']
stars_df_features['Sub_AV'] = stars_df_features['Amag'] + stars_df_features['Vmag']

stars_df_features.head()
# Out:
#    Vmag    Plx  e_Plx    B-V       Amag  TargetClass     Amag_SQ  Vmag_SQ  \
# 0  9.10   3.54   1.39  0.482  16.845016            3  283.754574  82.8100
# 1  9.27  21.90   3.10  0.999  20.972221            5  439.834036  85.9329
# 2  6.61   2.81   0.63 -0.019  13.853532            1  191.920338  43.6921
# 3  8.06   7.75   0.97  0.370  17.506509            3  306.477840  64.9636
# 4  8.55   2.87   1.11  0.902  15.839409            4  250.886893  73.1025
#
#      B-V_SQ     Sum_AV     Sub_AV
# 0  0.232324  25.945016  25.945016
# 1  0.998001  30.242221  30.242221
# 2  0.000361  20.463532  20.463532
# 3  0.136900  25.566509  25.566509
# 4  0.813604  24.389409  24.389409

# %%
for i in stars_df_features.columns.tolist():
    stars_df_features [i] = stars_df_features[i] / stars_df_features[i].max()
stars_df_features.head()
# Out:
#        Vmag       Plx     e_Plx       B-V      Amag  TargetClass   Amag_SQ  \
# 0  0.710383  0.012631  0.042057  0.170018  0.575914     0.428571  0.331677
# 1  0.723653  0.078139  0.093797  0.352381  0.717019     0.714286  0.514117
# 2  0.516003  0.010026  0.019062 -0.006702  0.473639     0.142857  0.224333
# 3  0.629196  0.027652  0.029349  0.130511  0.598530     0.428571  0.358238
# 4  0.667447  0.010240  0.033585  0.318166  0.541534     0.571429  0.293259
#
#     Vmag_SQ    B-V_SQ    Sum_AV    Sub_AV
# 0  0.504643  0.028906  0.624885  0.624885
# 1  0.523674  0.124172  0.728383  0.728383
# 2  0.266259  0.000045  0.492864  0.492864
# 3  0.395888  0.017033  0.615769  0.615769
# 4  0.445486  0.101229  0.587418  0.587418

# %%
stars_df_features['TargetClass'] = stars_df_features['TargetClass'].astype('int64')

# %%
X = stars_df_features.drop('TargetClass', axis=1, inplace=False)
Y = stars_df_features['TargetClass']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state=21, stratify=Y)

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train,Y_train)
Y_pred = KNN.predict(X_test)
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score
print(classification_report(Y_test, Y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 3>()
#       1 model = KNeighborsClassifier(n_neighbors=5)
#       2 model.fit(X_train,Y_train)
# ----> 3 Y_pred = KNN.predict(X_test)
#       4 from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score
#       5 print(classification_report(Y_test, Y_pred))
#
# TypeError: predict() missing 1 required positional argument: 'X'

# %%
stardf['TargetClass'].value_counts()
# Out:
# 5    2733
# 3    2457
# 4    2178
# 2    1285
# 1     559
# 6     433
# 7      22
# 0      10
# Name: TargetClass, dtype: int64

# %%
Y_test.value_counts()
# Out:
# 0    1932
# 1       4
# Name: TargetClass, dtype: int64

# %%
Y_train.value_counts()
# Out:
# 0    7723
# 1      18
# Name: TargetClass, dtype: int64

# %%
Y_test

# %%
n_neigh = 15
K_best = 0
Score_best = 0

for i in range(1,n_neigh):
    KNN = KNeighborsClassifier(n_neighbors=i)
    KNN.fit(X_train,Y_train)
    Y_pred = KNN.predict(X_test)
    if KNN.score(X_test,Y_test) > Score_best:
        Score_best = KNN.score(X_test,Y_test)
        K_best = i
print("neighbors is {} with a test accuracy of {}%""".format(K_best, (Score_best*100)))
# Out:
# neighbors is 7 with a test accuracy of 99.74173553719008%

# %%
classifier = LogisticRegression()
classifier.fit(X_train, Y_train)

print(f"LR Training Data: {classifier.score(X_train, Y_train)}")
print(f"LR Testing Data: {classifier.score(X_test, Y_test)}")
# Out:
# LR Training Data: 0.9979330835809327
# LR Testing Data: 0.996900826446281

# %%
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

clf =RandomForestClassifier( random_state = 21).fit(X_train_scaled, Y_train)

y_pred=clf.predict(X_test_scaled)

print(f'RFC Training Data : {clf.score(X_train_scaled,Y_train)}')
print(f'RFC Testing Data: {clf.score(X_test_scaled,Y_test)}')
# Out:
# RFC Training Data : 1.0
# RFC Testing Data: 0.9979338842975206

# %%
from sklearn.datasets import make_blobs

# %%
fig,axes=plt.subplots (figsize=(12, 12))
X, Y = make_blobs(n_samples= 9677 , centers=8, random_state=0, cluster_std=0.9)
plt.scatter(X[:, 0], X[:, 1], c=Y, s=30, cmap="rainbow");


plt.show()

# %%
for i in range(8):
    print('--> label {}'.format(i))
    for j in range(X.shape[1]):
        print('std for feature {}: {}'.format(j, np.std(X[Y==i][:,j])))
# Out:
# --> label 0
# std for feature 0: 0.8822774632133329
# std for feature 1: 0.8715697691035813
# --> label 1
# std for feature 0: 0.8905806228762124
# std for feature 1: 0.8986825740144915
# --> label 2
# std for feature 0: 0.8896402252319812
# std for feature 1: 0.8890833106409319
# --> label 3
# std for feature 0: 0.9105638351817569
# std for feature 1: 0.8682162686342944
# --> label 4
# std for feature 0: 0.9142767466875098
# std for feature 1: 0.9040709622332853
# --> label 5
# std for feature 0: 0.8808216087221464
# std for feature 1: 0.8922800286176908
# --> label 6
# std for feature 0: 0.8875241362608144
# std for feature 1: 0.8690184074082911
# --> label 7
# std for feature 0: 0.8874949848758864
# std for feature 1: 0.8996479118419513

# %% [markdown]
# These are the scores without feature engineering included

# %%
x=stardf.drop("TargetClass",axis =1)
y=stardf["TargetClass"].values

x_train,x_test,y_train,y_test =train_test_split(x,y,random_state =21)

# %%
classifier = LogisticRegression()
classifier.fit(x_train, y_train)

print(f"LR Training Data: {classifier.score(x_train, y_train)}")
print(f"LR Testing Data: {classifier.score(x_test, y_test)}")
# Out:
# LR Training Data: 0.6498553121124432
# LR Testing Data: 0.6289256198347107
# C:\Users\Helen\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
scaler = StandardScaler().fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

clf =RandomForestClassifier( random_state = 21).fit(x_train_scaled, y_train)

y_pred=clf.predict(x_test_scaled)

print(f'RFC Training Data : {clf.score(x_train_scaled,y_train)}')
print(f'RFC Testing Data: {clf.score(x_test_scaled,y_test)}')
# Out:
# RFC Training Data : 1.0
# RFC Testing Data: 0.753305785123967

# %%
##realised that this was too low and it's because distance between values was too small, allowing for too much error. 
#classifying the data beforehand made things a lot simpler
